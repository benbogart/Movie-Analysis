# %% [markdown]
# ![Movie Image](images/film_reel.jpg)
#
# <span style="float:right">Photo by <a href="https://unsplash.com/@dmjdenise?utm_source=unsplash&amp;utm_medium=referral&amp;utm_content=creditCopyText">Denise Jans</a> on <a href="https://unsplash.com/s/photos/movie?utm_source=unsplash&amp;utm_medium=referral&amp;utm_content=creditCopyText">Unsplash</a></span>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Breaking-into-the-movie-industry" data-toc-modified-id="Breaking-into-the-movie-industry-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Breaking into the movie industry</a></span><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Business-Problem" data-toc-modified-id="Business-Problem-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Business Problem</a></span></li></ul></li><li><span><a href="#Which-Genres-are-the-most-Profitable?" data-toc-modified-id="Which-Genres-are-the-most-Profitable?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Which Genres are the most Profitable?</a></span><ul class="toc-item"><li><span><a href="#Prepare-Data" data-toc-modified-id="Prepare-Data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Prepare Data</a></span></li><li><span><a href="#Data-Understanding" data-toc-modified-id="Data-Understanding-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data Understanding</a></span><ul class="toc-item"><li><span><a href="#Clean-up-tn_movie_budgets-dataframe" data-toc-modified-id="Clean-up-tn_movie_budgets-dataframe-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Clean up tn_movie_budgets dataframe</a></span></li><li><span><a href="#Clean-up-imdb_title_basics" data-toc-modified-id="Clean-up-imdb_title_basics-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Clean up imdb_title_basics</a></span></li><li><span><a href="#Join-DataFrames" data-toc-modified-id="Join-DataFrames-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Join DataFrames</a></span></li></ul></li><li><span><a href="#Explore-Genre-Profitability" data-toc-modified-id="Explore-Genre-Profitability-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Explore Genre Profitability</a></span><ul class="toc-item"><li><span><a href="#Outliers" data-toc-modified-id="Outliers-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Outliers</a></span><ul class="toc-item"><li><span><a href="#View-outliers" data-toc-modified-id="View-outliers-2.3.1.1"><span class="toc-item-num">2.3.1.1&nbsp;&nbsp;</span>View outliers</a></span></li><li><span><a href="#Remove-Outliers-by-zscore" data-toc-modified-id="Remove-Outliers-by-zscore-2.3.1.2"><span class="toc-item-num">2.3.1.2&nbsp;&nbsp;</span>Remove Outliers by zscore</a></span></li><li><span><a href="#Remove-Outliers-by-IQR" data-toc-modified-id="Remove-Outliers-by-IQR-2.3.1.3"><span class="toc-item-num">2.3.1.3&nbsp;&nbsp;</span>Remove Outliers by IQR</a></span></li></ul></li></ul></li><li><span><a href="#Genre-Marketcap-by-year" data-toc-modified-id="Genre-Marketcap-by-year-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Genre Marketcap by year</a></span></li><li><span><a href="#Budget-Impact" data-toc-modified-id="Budget-Impact-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Budget Impact</a></span><ul class="toc-item"><li><span><a href="#Create-Budget-Class-Feature" data-toc-modified-id="Create-Budget-Class-Feature-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Create Budget Class Feature</a></span></li><li><span><a href="#Plot-Budget-Class" data-toc-modified-id="Plot-Budget-Class-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Plot Budget Class</a></span></li></ul></li><li><span><a href="#Most-profitable-Genres-by-Budget-Class-Box-Plot" data-toc-modified-id="Most-profitable-Genres-by-Budget-Class-Box-Plot-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Most profitable Genres by Budget Class Box Plot</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Breaking into the movie industry
# Author: Ben Bogart

# %% [markdown]
# ## Overview
# This is a case study for Microsoft, which has decided to open a new movie studio.  Microsoft needs to make make key decisions about the initial steps of creating their first movie including setting a budget, choosing which genres to focus on, and choosing whom to work with.  The data provided comes from IMDB, Box Office Mojo, Roten Tomatoes, The Movie Database, and TheNumbers.com.  The methodology includes joining, filtering, and visualizing the data to illustrate trends primarily related to ROI. The results show that Microsoft should focus on Horror and/or Mystery, spend between $6M - $14.2M, and look to partner with a short list of producers, writers, and actors listed at the end of question 3.

# %% [markdown]
# ## Business Problem
# Microsoft has decided to open a movie studio.  At this point they are at the beginning of their journey to understand the movie industry. They need information to make high level decisions that will increase their likelihood of success.  Success is defined as a profitable investment that allows for the creation of future movies and a long term acquisition of industry experience.  Making an incorrect decision about budget or how to spend money could lead to failure which would be both embarrassing for the company and result in a loss of money.
#
# This problem led to the the following three high level questions, which were chosen as they represent actionable first steps for breaking into the movie industry.
# * Which genres yield the highest ROI
# * What budget range in those genres yields the highest ROI
# * Who should Microsoft reach out to in the movie industry for partnerships

# %%
# import dependencies
import pandas as pd
import data_helpers.data_functions as data_functions
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.ticker as mtick

import seaborn as sns

import datetime as dt

# %% [markdown]
# # Which Genres are the most Profitable?

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ## Data Understanding
#
# The following Data was used for the first two questions
# * which genres produce the highest ROI?
# * What budget range in those genres yields the highest ROI
#
# The following tables are used from IMDB and TheNumbers.com:
# * tn_movie_budgets
# * imdb_title_basics
#
# `tn_movie_budgets` contains movie budgets and gross income figures by movie and year.
# `imdb_title_basics` contains title, release year, and genre.
#
# Because there is no key in common the tables have to be joined on release year and title, and errors in that process need to be evaluated.
#
# The data is stored in the data/zippedData directory of this repo.
#
# Because this project is spread across more than one notebook, some of the code has been consolidated into the included data_helpers package.

# %%
#import all of the available data
from data_helpers.data import data 
import data_helpers.data_functions as data_functions

# %%
#delme
for key in data.keys():
    print(key)
# Out:
# imdb_title_crew
# tmdb_movies
# imdb_title_akas
# imdb_title_ratings
# imdb_name_basics
# imdb_title_basics
# tn_movie_budgets
# bom_movie_gross
# imdb_title_principals
# rt_movie_info
# rt_reviews

# %% [markdown]
# ### Clean up tn_movie_budgets dataframe
#
# The function clean clean_tn_movie_budgets takes in the raw dataframe and does th following:
#
# 1. Converts the release_date column to datetime
# 1. converts amounts to int
# 1. Adds a release _year column for joining
# 1. removes rows where production budgets or worldwide gross == 0
# 1. Creates features for ROI and ROI_zscore

# %%
### Clean up tn_movie_budgets dataframe
movie_budgets = data_functions.clean_tn_movie_budgets(data['tn_movie_budgets'])

# %%
movie_budgets.head()
# Out:
#    release_date                                        movie  \
# id
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2019-06-07                                 Dark Phoenix
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget  domestic_gross  worldwide_gross  release_year  \
# id
# 1           425000000       760507625       2776345279          2009
# 2           410600000       241063875       1045663875          2011
# 3           350000000        42762350        149762350          2019
# 4           330600000       459005868       1403013963          2015
# 5           317000000       620181382       1316721747          2017
#
#            ROI  ROI_zscore
# id
# 1   553.257713    0.046157
# 2   154.667286   -0.084594
# 3   -57.210757   -0.154097
# 4   324.384139   -0.028921
# ...

# %%
movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5415 entries, 1 to 82
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5415 non-null   datetime64[ns]
#  1   movie              5415 non-null   object
#  2   production_budget  5415 non-null   int64
#  3   domestic_gross     5415 non-null   int64
#  4   worldwide_gross    5415 non-null   int64
#  5   release_year       5415 non-null   int64
#  6   ROI                5415 non-null   float64
#  7   ROI_zscore         5415 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(1)
# memory usage: 380.7+ KB

# %% [markdown]
# ### Clean up imdb_title_basics

# %%
#TODO: Explore other options to copy

title_basics = data['imdb_title_basics'].copy()
title_basics.head()

# Drop original_title and runtime_minutes which we don't need for this question
title_basics.drop(['original_title', 'runtime_minutes'], axis = 1, inplace = True)

#drop missing genres and convert remaining to list
title_basics = title_basics.dropna(subset=['genres']).reset_index()
title_basics['genres'] = title_basics['genres'].map(lambda x: x.split(','))

# %%
title_basics.head()
# Out:
#       tconst                    primary_title  start_year  \
# 0  tt0063540                        Sunghursh        2013
# 1  tt0066787  One Day Before the Rainy Season        2019
# 2  tt0069049       The Other Side of the Wind        2018
# 3  tt0069204                  Sabse Bada Sukh        2018
# 4  tt0100275         The Wandering Soap Opera        2017
#
#                      genres
# 0    [Action, Crime, Drama]
# 1        [Biography, Drama]
# 2                   [Drama]
# 3           [Comedy, Drama]
# 4  [Comedy, Drama, Fantasy]

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140736 entries, 0 to 140735
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         140736 non-null  object
#  1   primary_title  140736 non-null  object
#  2   start_year     140736 non-null  int64
#  3   genres         140736 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 4.3+ MB

# %%
Since we don't know which of the duplicated movies is correct we will drop 
them all.  If we don't we could end up identifying the wrong people as profitable
which would be worse than not identifying a profitable person.

# %% [markdown]
# **NOTE:** There appear to be duplicate entries in this dataset, but we don't want to remove them yet because join

# %%
title_basics[title_basics.duplicated(
    subset = ['primary_title', 'start_year'],
    keep=False
    )].sort_values(['primary_title', 'start_year'])
# Out:
#            tconst                           primary_title  start_year  \
# 101164  tt6085916                               (aguirre)        2016
# 103392  tt6214664                               (aguirre)        2016
# 125145  tt8032828                100 Milioni di bracciate        2017
# 125162  tt8034014                100 Milioni di bracciate        2017
# 19649   tt1855110                                     180        2011
# ...           ...                                     ...         ...
# 65327   tt3815126  Ângelo de Sousa - Tudo o Que Sou Capaz        2010
# 65328   tt3815128  Ângelo de Sousa - Tudo o Que Sou Capaz        2010
# 65329   tt3815130  Ângelo de Sousa - Tudo o Que Sou Capaz        2010
# 65330   tt3815132  Ângelo de Sousa - Tudo o Que Sou Capaz        2010
# 65331   tt3815134  Ângelo de Sousa - Tudo o Que Sou Capaz        2010
#
#                                   genres
# 101164          [Biography, Documentary]
# 103392  [Biography, Comedy, Documentary]
# ...

# %% [markdown]
# ### Join DataFrames

# %%
df = pd.merge(movie_budgets, title_basics.reset_index(),
             left_on=['movie', 'release_year'],
             right_on=['primary_title', 'start_year'])
df = df.drop(['primary_title','start_year'], axis=1)

df.head()
# Out:
#   release_date                                        movie  \
# 0   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1   2019-06-07                                 Dark Phoenix
# 2   2015-05-01                      Avengers: Age of Ultron
# 3   2018-04-27                       Avengers: Infinity War
# 4   2017-11-17                               Justice League
#
#    production_budget  domestic_gross  worldwide_gross  release_year  \
# 0          410600000       241063875       1045663875          2011
# 1          350000000        42762350        149762350          2019
# 2          330600000       459005868       1403013963          2015
# 3          300000000       678815482       2048134200          2018
# 4          300000000       229024295        655945209          2017
#
#           ROI  ROI_zscore   index     tconst                        genres
# 0  154.667286   -0.084594    5920  tt1298650  [Action, Adventure, Fantasy]
# ...

# %%
df[df['movie'] == 'Cinderella']
# Out:
#     release_date       movie  production_budget  domestic_gross  \
# 228   2015-03-13  Cinderella           95000000       201151353
# 229   2015-03-13  Cinderella           95000000       201151353
#
#      worldwide_gross  release_year         ROI  ROI_zscore  index     tconst  \
# 228        534551353          2015  462.685635    0.016447  11795  tt1661199
# 229        534551353          2015  462.685635    0.016447  85404  tt5089556
#
#                        genres
# 228  [Drama, Family, Fantasy]
# 229                 [Fantasy]

# %%
df[df.duplicated(
    subset = ['movie', 'release_year'],
    keep=False
    )].sort_values(['movie', 'release_year']).head()
# Out:
#      release_date          movie  production_budget  domestic_gross  \
# 1076   2011-06-24  A Better Life           10000000         1759252
# 1077   2011-06-24  A Better Life           10000000         1759252
# 572    2011-09-23      Abduction           35000000        28087155
# 573    2011-09-23      Abduction           35000000        28087155
# 1411   2011-12-31       Absentia              70000               0
#
#       worldwide_gross  release_year         ROI  ROI_zscore  index     tconst  \
# 1076          1884251          2011  -81.157490   -0.161953   8795  tt1554091
# 1077          1884251          2011  -81.157490   -0.161953  24956  tt2027265
# 572          86648359          2011  147.566740   -0.086923   9907  tt1600195
# 573          86648359          2011  147.566740   -0.086923  39363  tt2447982
# 1411             8555          2011  -87.778571   -0.164125  10226  tt1610996
#
#                            genres
# 1076             [Drama, Romance]
# ...

# %%
#if we only keep the first
df[df.duplicated(
    subset = ['movie', 'release_year'],
    keep='first'
    )].sort_values(['movie', 'release_year']).shape
# Out:
# (52, 11)

# %%
# duplicates keeping only the first.
df = df[~df.duplicated(
        subset = ['movie', 'release_year'],
        keep='first'
        )].sort_values(['movie', 'release_year'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1366 entries, 1183 to 263
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       1366 non-null   datetime64[ns]
#  1   movie              1366 non-null   object
#  2   production_budget  1366 non-null   int64
#  3   domestic_gross     1366 non-null   int64
#  4   worldwide_gross    1366 non-null   int64
#  5   release_year       1366 non-null   int64
#  6   ROI                1366 non-null   float64
#  7   ROI_zscore         1366 non-null   float64
#  8   index              1366 non-null   int64
#  9   tconst             1366 non-null   object
#  10  genres             1366 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(3)
# memory usage: 128.1+ KB

# %%
# explode the genres for grouping
df = df.explode('genres')

# %%
#are there na values?
df.genres.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Explore Genre Profitability

# %%
# calculate ROI for each film
df['ROI'] = data_functions.calculate_roi(df['production_budget'], df['worldwide_gross'])

# %%
df.head()
# Out:
#      release_date                  movie  production_budget  domestic_gross  \
# 1183   2016-03-11    10 Cloverfield Lane            5000000        72082999
# 1183   2016-03-11    10 Cloverfield Lane            5000000        72082999
# 1183   2016-03-11    10 Cloverfield Lane            5000000        72082999
# 1018   2015-11-11  10 Days in a Madhouse           12000000           14616
# 562    2018-01-19              12 Strong           35000000        45819713
#
#       worldwide_gross  release_year          ROI  ROI_zscore  index  \
# 1183        108286422          2016  2065.728440    0.542300   5235
# 1183        108286422          2016  2065.728440    0.542300   5235
# 1183        108286422          2016  2065.728440    0.542300   5235
# 1018            14616          2015   -99.878200   -0.168094  57910
# 562          71118378          2018   103.195366   -0.101479   6854
#
#          tconst   genres
# 1183  tt1179933    Drama
# 1183  tt1179933   Horror
# ...

# %%
# groupby genre to get mean ROI
genre_ROI = df[['genres', 'ROI']].groupby('genres').mean()
genre_ROI = genre_ROI['ROI'] #just need a series
genre_ROI = genre_ROI.sort_values(ascending = False)
plt.figure(figsize = (12,6))
ax = sns.barplot(y = genre_ROI, x = genre_ROI.index, palette='Blues_r')
plt.xticks(rotation = 45, ha='right');

genre_ROI.head()
# Out:
# genres
# Horror       966.561948
# Mystery      944.029296
# Thriller     595.350342
# Sci-Fi       284.919637
# Animation    278.690125
# Name: ROI, dtype: float64

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = genre_ROI, y = genre_ROI.index, palette='Blues_r')
# Out:
# <AxesSubplot:xlabel='ROI', ylabel='genres'>

# %% [markdown]
# ### Outliers
# #### View outliers
# Are outliers dramatically affecting the most profitable genres?

# %%
plt.figure(figsize = (9,6))
sns.scatterplot(data = df, x = 'production_budget', y = 'ROI')

sns.catplot(x="genres", y="ROI",
            kind="box", 
            showfliers = True,
            data = df, height=6, aspect=1.5)
plt.xticks(rotation = 90);

# %% [markdown]
# #### Remove Outliers by zscore

# %%
# calculate overall zscore
#df['ROI_zscore'] = zscore(df['ROI'])

# TODO: This is sqewed, needs to use un-exploded df
#Moved to clean_tn_movie_budgets function

# %%
from scipy.stats import zscore

# we already have the ROI_score in the df.
# find the ROI zscore for ROI by genre.
df['ROI_zscore_by_genre'] = df.groupby('genres').transform(zscore)['ROI'] #.reset_index()

# %%
print('Number of ROI Outliers (zscore): ', df[df['ROI_zscore'] > 3].shape[0])
print('Number of ROI Outliers by Genre(zscore): ', df[df['ROI_zscore_by_genre'] > 3].shape[0])
# Out:
# Number of ROI Outliers (zscore):  4
# Number of ROI Outliers by Genre(zscore):  58

# %%
# Plot Both to see if there is a big difference
df_no_outliers = df[df['ROI_zscore'] <= 3]
df_no_genre_outliers = df_no_outliers[df_no_outliers['ROI_zscore_by_genre'] <= 3]

plt.figure(figsize = (9,6))
sns.scatterplot(data = df_no_outliers, x = 'production_budget', y = 'ROI', hue='genres')

plt.figure(figsize = (9,6))
sns.scatterplot(data = df_no_genre_outliers, x = 'production_budget', y = 'ROI', hue='genres')
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='ROI'>

# %%
genre_ROI = df_no_outliers[['genres', 'ROI']].groupby('genres').mean()
genre_ROI = genre_ROI['ROI'] #just need a series
genre_ROI = genre_ROI.sort_values(ascending = False)

plt.figure(figsize = (12,6))
ax = sns.barplot(y = genre_ROI, x = genre_ROI.index, palette='Blues_r')
plt.xticks(rotation = 45, ha='right');

# %%
genre_ROI = df_no_genre_outliers[['genres', 'ROI']].groupby('genres').mean()
genre_ROI = genre_ROI['ROI'] #just need a series
genre_ROI = genre_ROI.sort_values(ascending = False)

plt.figure(figsize = (12,6))
ax = sns.barplot(y = genre_ROI, x = genre_ROI.index, palette='Blues_r')
plt.xticks(rotation = 45, ha='right');

# %% [markdown]
# #### Remove Outliers by IQR

# %%
# #Calculate IQR by genre

# Computing IQR
iqr = pd.DataFrame()
iqr['Q1'] = df.groupby('genres').ROI.quantile(.25)
iqr['Q3'] = df.groupby('genres').ROI.quantile(.75)
iqr['IQR'] = iqr['Q3'] - iqr['Q1']
iqr['upper_thresh'] = iqr['Q3'] + 1.5*iqr['IQR']
iqr['lower_thresh'] = iqr['Q1'] - 1.5*iqr['IQR']
iqr.head()
# Out:
#                   Q1          Q3         IQR  upper_thresh  lower_thresh
# genres
# Action     11.141732  265.626834  254.485103    647.354488   -370.585922
# Adventure  57.262728  306.581470  249.318742    680.559583   -316.715384
# Animation  88.758585  344.781974  256.023389    728.817058   -295.276498
# Biography -26.218484  320.532740  346.751224    840.659576   -546.345320
# Comedy     27.621821  319.146376  291.524555    756.433208   -409.665012

# %%
df['iqr_upperthresh'] = df['genres'].map(iqr['upper_thresh'])
df_no_genre_outliers_aggressive = df[df['ROI'] < df['iqr_upperthresh']]#.copy()

# %%
# elimnate genres with fewer than 50 movies
genre_count = df_no_genre_outliers_aggressive[['genres', 'ROI']].groupby('genres').count()
genre_count = genre_count['ROI']
genre_count = genre_count[genre_count > 50]
genre_count.sort_values(ascending=False)

df_no_genre_outliers_aggressive = df_no_genre_outliers_aggressive[df_no_genre_outliers_aggressive['genres'].isin(genre_count.index)]

# %%
plt.figure(figsize = (9,6))
sns.scatterplot(data = df_no_genre_outliers_aggressive, 
                x = 'production_budget', y = 'ROI', hue='genres')


df_no_genre_outliers_aggressive.loc[:, 'mean_genre_ROI'] = \
    df_no_genre_outliers_aggressive.groupby('genres').ROI.mean()

df_no_genre_outliers_aggressive = df_no_genre_outliers_aggressive.sort_values(by = 'mean_genre_ROI', ascending = False)


sns.catplot(x="genres", y="ROI",
            kind="box", 
            showfliers = True,
            data = df_no_genre_outliers_aggressive, height=6, aspect=1.5)
plt.xticks(rotation = 90);

# %%
df_no_genre_outliers_aggressive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3114 entries, 1018 to 263
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   release_date         3114 non-null   datetime64[ns]
#  1   movie                3114 non-null   object
#  2   production_budget    3114 non-null   int64
#  3   domestic_gross       3114 non-null   int64
#  4   worldwide_gross      3114 non-null   int64
#  5   release_year         3114 non-null   int64
#  6   ROI                  3114 non-null   float64
#  7   ROI_zscore           3114 non-null   float64
#  8   index                3114 non-null   int64
#  9   tconst               3114 non-null   object
#  10  genres               3114 non-null   object
#  11  ROI_zscore_by_genre  3114 non-null   float64
#  12  iqr_upperthresh      3114 non-null   float64
#  13  mean_genre_ROI       0 non-null      float64
# dtypes: datetime64[ns](1), float64(5), int64(5), object(3)
# ...

# %%
genre_ROI = df_no_genre_outliers_aggressive[['genres', 'ROI']].groupby('genres').mean()
genre_ROI = genre_ROI['ROI'] #just need a series
genre_ROI = genre_ROI.sort_values(ascending = False)

plt.figure(figsize = (12,6))

clrs = ['grey' for x in genre_ROI.index ]
clrs[0] = '#EEC643'
clrs[1] = '#42D9C8'

ax = sns.barplot(y = genre_ROI, x = genre_ROI.index, palette=clrs)#palette='Blues_r')

plt.xticks(rotation = 45, ha='right');
plt.xlabel('Genre')
sns.despine()

plt.title('Average ROI by Genre (alltime)')

ax.yaxis.set_major_formatter(mtick.PercentFormatter())

# %% [markdown]
# ## Genre Marketcap by year

# %%
df_no_genre_outliers_aggressive.head()
# Out:
#      release_date                  movie  production_budget  domestic_gross  \
# 1018   2015-11-11  10 Days in a Madhouse           12000000           14616
# 562    2018-01-19              12 Strong           35000000        45819713
# 562    2018-01-19              12 Strong           35000000        45819713
# 799    2013-10-18       12 Years a Slave           20000000        56671993
# 799    2013-10-18       12 Years a Slave           20000000        56671993
#
#       worldwide_gross  release_year         ROI  ROI_zscore  index     tconst  \
# 1018            14616          2015  -99.878200   -0.168094  57910  tt3453052
# 562          71118378          2018  103.195366   -0.101479   6854  tt1413492
# 562          71118378          2018  103.195366   -0.101479   6854  tt1413492
# 799         181025343          2013  805.126715    0.128779  24879  tt2024544
# 799         181025343          2013  805.126715    0.128779  24879  tt2024544
#
# ...

# %%
market_trend = df_no_genre_outliers_aggressive.groupby(['genres', 'release_year']).agg(cap = ('worldwide_gross', 'sum'))


plt.figure(figsize = (12, 9))
sns.lineplot(data = market_trend.reset_index(),
            x = 'release_year',
            y = 'cap',
            hue = 'genres',
            hue_order= ['Horror', 'Mystery', 'Sci-Fi', 'Animation'])
market_trend.head()
# Out:
#                              cap
# genres release_year
# Action 2010           7084992745
#        2011           9537986409
#        2012          10157794678
#        2013          10178182323
#        2014          13391879925

# %%
df_no_genre_outliers_aggressive['date_ordinal'] = pd.to_datetime(df_no_genre_outliers_aggressive['release_date']).apply(lambda date: date.toordinal())

plt.figure(figsize = (12, 9))
ax = sns.regplot(data = df_no_genre_outliers_aggressive[df_no_genre_outliers_aggressive['genres'] == 'Horror'],
            x = 'date_ordinal',
            y = 'ROI',
            color = '#EEC643',
            label = 'Horror')

sns.regplot(data = df_no_genre_outliers_aggressive[df_no_genre_outliers_aggressive['genres'] == 'Mystery'],
            x = 'date_ordinal',
            y = 'ROI',
            color = '#42D9C8',
            ax = ax,
            label = 'Mystery')

ax.set_xlim(df_no_genre_outliers_aggressive['date_ordinal'].min() - 1, df_no_genre_outliers_aggressive['date_ordinal'].max() + 1)

# sns.regplot(data = df_no_genre_outliers_aggressive[df_no_genre_outliers_aggressive['genres'] == 'Sci-Fi'],
#             x = 'date_ordinal',
#             y = 'ROI',
#             ax = ax)

# sns.regplot(data = df_no_genre_outliers_aggressive[df_no_genre_outliers_aggressive['genres'] == 'Animation'],
#             x = 'date_ordinal',
#             y = 'ROI',
#             ax = ax)

ax.set_xlabel('Date')

#Change X axis to years 2011 - 2018
ticks = []
for year in range(2010, 2020):
    year = '-'.join([str(year),'01','01'])
    ticks.append(pd.to_datetime(year).toordinal())

ax.set_xticks(ticks)
new_labels = [dt.date.fromordinal(int(item)).year for item in ax.get_xticks()]
ax.set_xticklabels(new_labels)

plt.legend() #fontsize="large")

sns.set_context('poster')

ax.yaxis.set_major_formatter(mtick.PercentFormatter())

sns.despine()

plt.title('ROI Trend overtime')
# Out:
# Text(0.5, 1.0, 'ROI Trend overtime')

# %% [markdown]
# ## Budget Impact

# %%
df_no_genre_outliers_aggressive[['production_budget', 'ROI']].corr()
# Out:
#                    production_budget       ROI
# production_budget           1.000000  0.111693
# ROI                         0.111693  1.000000

# %%
plt.figure(figsize = (12, 9))

ax = sns.regplot(data = df_no_genre_outliers_aggressive[df_no_genre_outliers_aggressive['genres'] == 'Mystery'],
                x='production_budget',
                y='ROI',
                label = 'Mystery',
                scatter_kws={'alpha':0.5, 's':15})

sns.regplot(data = df_no_genre_outliers_aggressive[df_no_genre_outliers_aggressive['genres'] == 'Horror'],
                x='production_budget',
                y='ROI',
                label = 'Horror',
                scatter_kws={'alpha':0.5, 's':15})

plt.legend() #fontsize="large")

sns.set_context('poster')

ax.yaxis.set_major_formatter(mtick.PercentFormatter())

sns.despine()

plt.title('Budget ROI Relationship')

ax.set_ylim(- 100, 1000)
#ax.set_xlim(0, 200000000)

new_labels = [item / 1000000 for item in ax.get_xticks()]
ax.set_xticklabels(new_labels)

plt.xlabel('Production Budget in Millions of USD')
# Out:
# <ipython-input-42-08dec410ea76>:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels)
# Text(0.5, 0, 'Production Budget in Millions of USD')

# %% [markdown]
# Over all genres, the budget and the ROI are not very correlated.

# %% [markdown]
# ### Create Budget Class Feature
#
# Does budget threshold change the ROI distribution?  We could build a a feature and see which does best for ROI.
#
#
# Here are the thresholds for the various unions:
#
#     The DGA and SAG thresholds for low budget are similar: $2.6 and $2.5 million respectively. The writer’s guild draws the line way down at $1.2 million.
#
#     IATSE (the union that covers most of the below-the-line crew) has three different tiers: below $6 million, between $6 and $10 million, and $10 to $14.2 million. (Anything above that is full union rates.) To give you a sense of scale, Get Out only cost $4.5 million. Then again, not paying the crew full union wages and benefits is probably how Blumhouse keep their films profitable.
#
# Source: http://www.anonymousproductionassistant.com/2018/01/17/low-budget-movie/

# %%
bc_df = df_no_genre_outliers_aggressive.copy()

# %%
bc_df['budget_class'] = bc_df['production_budget'].apply(data_functions.get_budget_class)
bc_df.head()
# Out:
#      release_date                  movie  production_budget  domestic_gross  \
# 1018   2015-11-11  10 Days in a Madhouse           12000000           14616
# 562    2018-01-19              12 Strong           35000000        45819713
# 562    2018-01-19              12 Strong           35000000        45819713
# 799    2013-10-18       12 Years a Slave           20000000        56671993
# 799    2013-10-18       12 Years a Slave           20000000        56671993
#
#       worldwide_gross  release_year         ROI  ROI_zscore  index     tconst  \
# 1018            14616          2015  -99.878200   -0.168094  57910  tt3453052
# 562          71118378          2018  103.195366   -0.101479   6854  tt1413492
# 562          71118378          2018  103.195366   -0.101479   6854  tt1413492
# 799         181025343          2013  805.126715    0.128779  24879  tt2024544
# 799         181025343          2013  805.126715    0.128779  24879  tt2024544
#
# ...

# %%
#create a df with top grenes by average genre_ROI
top_genres = bc_df[['genres', 'ROI']].groupby('genres').mean()
top_genres.columns = ['mean_ROI']
top_genres = top_genres.sort_values(by = 'mean_ROI', ascending = False)
top_genres.head()
# Out:
#              mean_ROI
# genres
# Horror     310.119013
# Mystery    264.561566
# Sci-Fi     230.702812
# Animation  219.539975
# Romance    185.128568

# %% [markdown]
# ### Plot Budget Class

# %%
sns.catplot(x="genres", 
            y="ROI", 
            hue="budget_class", 
            hue_order=['under 6m', '6-10m', '10-14.2m', '14.2m +'], 
            kind="box", 
            height = 6,
            aspect = 1.5,
            showfliers = False, 
            data=bc_df[bc_df['genres'].isin(top_genres.index[:2])])

# %%
#Check how many films are in each budget_class by Category
bc_df.groupby(['genres', 'budget_class']).tconst.nunique()[['Horror', 'Mystery']]
# Out:
# genres   budget_class
# Horror   10-14.2m        22
#          14.2m +         58
#          6-10m           13
#          under 6m         4
# Mystery  10-14.2m        18
#          14.2m +         56
#          6-10m           10
#          under 6m         2
# Name: tconst, dtype: int64

# %% [markdown]
# Drop the under 6m category, not enough data

# %% [markdown]
# ## Most profitable Genres by Budget Class Box Plot

# %%
plt.figure(figsize = (12, 9))

ax = sns.catplot(x="genres", 
            y="ROI", 
            hue="budget_class", 
            hue_order=['6-10m', '10-14.2m', '14.2m +'], 
            kind="box", 
            height = 9,
            aspect = 1.25,
            showfliers = False, 
            data=bc_df[bc_df['genres'].isin(top_genres.index[:2])])

ax._legend.set_title('Budget Class')

plt.title('Profitability by Budget Class')
plt.xlabel('Genre')
# Out:
# Text(0.5, 21.92, 'Genre')
